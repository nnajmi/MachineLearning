# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import matplotlib.ticker as ticker
from matplotlib import dates as mdates
import copy

# %matplotlib inline

# %%
data = pd.read_csv("pollution_us_2000_2016.csv/pollution_california_2000_2016.csv")
#Here is the first five rows of the dataset using the head function
data.head()

# %%
from pandas import set_option
set_option('precision', 4)

# %%
data['Date Local'] = pd.to_datetime(data['Date Local'],format='%m/%d/%Y')

# %%
import os
os.environ['PROJ_LIB'] = 'C:/Users/viole/Anaconda3/Lib/site-packages/mpl_toolkits/basemap'
from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon
import shapefile
# %matplotlib nbagg

# %%
fig = plt.figure(figsize=(10,5))
map = Basemap(llcrnrlon=-119,llcrnrlat=22,urcrnrlon=-64,urcrnrlat=49,projection='lcc',lat_1=33,lat_2=45,lon_0=-95)
# # I commented shapefile out...
#map.readshapefile('st99_d00', name='states', drawbounds=True)
map.drawcoastlines()
#map.drawmapboundary(fill_color='#9fdbff',zorder=1)
#map.fillcontinents(color='#f0f8ff',lake_color='#9fdbff',alpha=0.8,zorder=1.5)
#map.drawcountries(linewidth=1.5, color='darkblue')
map.drawstates()
ax = plt.gca()

# %%
fig = plt.figure(figsize=(10,5))
m = Basemap(projection='cyl', resolution='l',llcrnrlat=-90, urcrnrlat = 90,llcrnrlon=-180, urcrnrlon = 180)
m.drawcoastlines(linewidth=0.5)
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
# 1. Draw the map background
fig = plt.figure(figsize=(8, 8))
m = Basemap(projection='lcc', resolution='h', 
            lat_0=37.5, lon_0=-119,
            width=1E6, height=1.2E6)
#m.shadedrelief()
m.drawcoastlines(color='gray')
m.drawcountries(color='gray')
m.drawstates(color='gray')
m.drawcounties(color='red')
# Out:
# <img src="data:image/png;base64,..." width="576">

# %%
## Create the map
plt.figure(figsize=(10,8))
map = Basemap(llcrnrlon=-123,llcrnrlat=29,urcrnrlon=-115,urcrnrlat=45, projection='lcc',lat_1=33,lat_2=45,lon_0=-95)
# Load the shapefile, use 'counties'
map.readshapefile('ca-county-boundaries/CA_Counties/CA_Counties_TIGER2016',name='counties',drawbounds=True)
map.drawcounties()

# Collect the county names from the shapefile attributes
# county_names = []
# for shape_dict in map.counties_info:
#     county_names.append(shape_dict['NAME'])
    
# ax = plt.gca()
# cmap, norm = mpl.colors.from_levels_and_colors([0,50,100,150,200,300,500], ['green','yellow','orange','red','purple','maroon'])
# m = mpl.cm.ScalarMappable(norm=norm, cmap=cmap)

# for i,county in enumerate(aqiO3Cal.index):
#     color = m.to_rgba(aqiO3Cal['O3 AQI'][county])
#     seg = map.counties[county_names.index(county)]
#     poly = Polygon(seg, facecolor=color,edgecolor=color)
#     ax.add_patch(poly)

plt.title('2009-08-31 AQI O3 in California')
plt.show()
# Out:
# <div id='4e030a3d-d8b2-4a47-a486-935301eb4c8c'></div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-7a4b75721bb1> in <module>
#       6 #map = Basemap(llcrnrlon=-123,llcrnrlat=29,urcrnrlon=-115,urcrnrlat=45, projection='lcc',lat_1=33,lat_2=45,lon_0=-95)
#       7 # Load the shapefile, use 'counties'
# ----> 8 map.readshapefile('ca-county-boundaries/CA_Counties/CA_Counties_TIGER2016',name='counties',drawbounds=True)
#       9 map.drawcounties()
#      10
#
# ~\anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in readshapefile(self, shapefile, name, drawbounds, zorder, linewidth, color, antialiased, ax, default_encoding)
#    2187                     lons, lats = list(zip(*verts[indx1:indx2]))
#    2188                     if max(lons) > 721. or min(lons) < -721. or max(lats) > 90.01 or min(lats) < -90.01:
# -> 2189                         raise ValueError(msg)
#    2190                     # if latitude is slightly greater than 90, truncate to 90
#    2191                     lats = [max(min(lat, 90.0), -90.0) for lat in lats]
#
# ValueError: shapefile must have lat/lon vertices  - it looks like this one has vertices
# in map projection coordinates. You can convert the shapefile to geographic
# coordinates using the shpproj utility from the shapelib tools
# (http://shapelib.maptools.org/shapelib-tools.html)
