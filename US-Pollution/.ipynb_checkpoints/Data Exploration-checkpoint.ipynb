# %% [markdown]
# # COMP 514 - Data Mining Project

# %% [markdown]
# * Group 1:
# * Project Assigment 3: Data Exploration

# %% [markdown]
# # California Pollution 2000 - 2016

# %% [markdown]
# The original dataset consists of the pollution data of the United States for years 2000 to 2016. As discussed in the class, we tailored the data for only the state of California for years 2000 to 2016.
# <br> The dataset consists of the data of four major air pollutants including NO2, O3, SO2 and CO.
# The dataset has the mean, max and AQI value of these four pollutants in different areas of California for the years 2000 to 2016.
# <br>As it is shown below, there are **576142 tuples/rows** as well as **25 attributes/columns** in the dataset.

# %% [markdown]
# According to data.info(), there are null values in two columns: **SO2 AQI** and **CO AQI**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("pollution_us_2000_2016.csv/pollution_california_2000_2016.csv")
#Here is the first five rows of the dataset using the head function
data.head()
# Out:
#      id  State Code  County Code  Site Num                 Address  \
# 0  3516           6           13         2  2956-A TREAT BOULEVARD
# 1  3517           6           13         2  2956-A TREAT BOULEVARD
# 2  3518           6           13         2  2956-A TREAT BOULEVARD
# 3  3519           6           13         2  2956-A TREAT BOULEVARD
# 4  3520           6           13         2  2956-A TREAT BOULEVARD
#
#         State        County     City Date Local  NO2 Mean  ...  \
# 0  California  Contra Costa  Concord   1/1/2000     14.78  ...
# 1  California  Contra Costa  Concord   1/1/2000     14.78  ...
# 2  California  Contra Costa  Concord   1/1/2000     14.78  ...
# 3  California  Contra Costa  Concord   1/1/2000     14.78  ...
# 4  California  Contra Costa  Concord   1/2/2000     16.04  ...
#
#    O3 1st Max Hour  O3 AQI  SO2 Mean  SO2 1st Max Value  SO2 1st Max Hour  \
# 0               13      25      0.64                2.0                 9
# 1               13      25      0.64                2.0                 9
# 2               13      25      0.60                2.0                11
# 3               13      25      0.60                2.0                11
# 4                9      27      1.00                2.0                 5
#
#    SO2 AQI  CO Mean  CO 1st Max Value  CO 1st Max Hour  CO AQI
# 0      3.0     0.56               1.3                4     NaN
# 1      3.0     0.57               0.8                6     9.0
# 2      NaN     0.56               1.3                4     NaN
# 3      NaN     0.57               0.8                6     9.0
# 4      3.0     0.58               1.1               21     NaN
#
# [5 rows x 25 columns]

# %%
#Using shape we can see the number of tuples and attributes in our dataset
data.shape
# Out:
# (576142, 25)

# %%
#Info function gives us the datatype for each attribute as well as the number of the null values for that attribute 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576142 entries, 0 to 576141
# Data columns (total 25 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 576142 non-null  int64
#  1   State Code         576142 non-null  int64
#  2   County Code        576142 non-null  int64
#  3   Site Num           576142 non-null  int64
#  4   Address            576142 non-null  object
#  5   State              576142 non-null  object
#  6   County             576142 non-null  object
#  7   City               576142 non-null  object
#  8   Date Local         576142 non-null  object
#  9   NO2 Mean           576142 non-null  float64
#  10  NO2 1st Max Value  576142 non-null  float64
#  11  NO2 1st Max Hour   576142 non-null  int64
#  12  NO2 AQI            576142 non-null  int64
#  13  O3 Mean            576142 non-null  float64
#  14  O3 1st Max Value   576142 non-null  float64
#  15  O3 1st Max Hour    576142 non-null  int64
#  16  O3 AQI             576142 non-null  int64
#  17  SO2 Mean           576142 non-null  float64
#  18  SO2 1st Max Value  576142 non-null  float64
#  19  SO2 1st Max Hour   576142 non-null  int64
#  20  SO2 AQI            288232 non-null  float64
#  21  CO Mean            576142 non-null  float64
#  22  CO 1st Max Value   576142 non-null  float64
#  23  CO 1st Max Hour    576142 non-null  int64
#  24  CO AQI             288060 non-null  float64
# dtypes: float64(10), int64(10), object(5)
# memory usage: 109.9+ MB

# %% [markdown]
# ### Basic Statistical Description of the Dataset

# %% [markdown]
# We removed the first four columns of data.describe() (including the statistics for 'id', 'State Code', 'County Code', 'Site Num') for better readibility of the data.
#
# <br> Based on the table below, the range of the AQI values vary from *Good (0<AQI<50)* to *Very Unhealthy* .
# <br> The mean and std for **SO2 AQI** and **CO AQI** is smaller than **NO2 AQI** and **O3 AQI**, so the data is less dispered for **SO2** and **CO AQI**.

# %%
from pandas import set_option
set_option('precision', 4)
df = data.describe()
df.iloc[:, 4:]
# Out:
#           NO2 Mean  NO2 1st Max Value  NO2 1st Max Hour      NO2 AQI  \
# count  576142.0000        576142.0000       576142.0000  576142.0000
# mean       13.6519            25.5921           11.2644      24.1102
# std        11.0819            18.0266            7.3783      17.1299
# min        -1.8714            -1.6000            0.0000       0.0000
# 25%         5.1818            11.0000            6.0000      10.0000
# 50%        10.9440            23.0000            9.0000      22.0000
# 75%        19.5455            37.0000           19.0000      35.0000
# max        98.1304           262.0000           23.0000     131.0000
#
#            O3 Mean  O3 1st Max Value  O3 1st Max Hour       O3 AQI  \
# count  576142.0000       576142.0000      576142.0000  576142.0000
# mean        0.0261            0.0388          10.2045      35.7227
# std         0.0115            0.0150           3.7114      20.4324
# min         0.0000            0.0000           0.0000       0.0000
# 25%         0.0177            0.0290           9.0000      25.0000
# 50%         0.0260            0.0380          10.0000      32.0000
# 75%         0.0340            0.0470          11.0000      40.0000
# max         0.0862            0.1400          23.0000     218.0000
#
#           SO2 Mean  SO2 1st Max Value  SO2 1st Max Hour      SO2 AQI  \
# count  576142.0000        576142.0000       576142.0000  288232.0000
# mean        1.1467             2.3318            8.5087       3.5983
# std         1.4063             3.1973            6.3228       5.1959
# min        -1.5217            -1.3000            0.0000       0.0000
# 25%         0.1571             0.6000            2.0000       1.0000
# 50%         0.7600             1.3000            8.0000       3.0000
# 75%         1.5565             3.0000           12.0000       4.0000
# max        40.2714           192.0000           23.0000     153.0000
#
#            CO Mean  CO 1st Max Value  CO 1st Max Hour       CO AQI
# count  576142.0000       576142.0000      576142.0000  288060.0000
# mean        0.4475            0.7693           7.4309       7.4057
# std         0.3759            0.7986           7.2335       7.1838
# min        -0.4000           -0.4000           0.0000       0.0000
# 25%         0.2208            0.3000           0.0000       3.0000
# 50%         0.3435            0.5000           6.0000       6.0000
# 75%         0.5522            1.0000          10.0000       9.0000
# max         7.5083           19.9000          23.0000     201.0000

# %%
#Range of the attributes 
df.loc['range'] = df.loc['max'] - df.loc['min']
pd.DataFrame(df.loc['range'])
# Out:
#                         range
# id                 45879.0000
# State Code             0.0000
# County Code          110.0000
# Site Num            8000.0000
# NO2 Mean             100.0019
# NO2 1st Max Value    263.6000
# NO2 1st Max Hour      23.0000
# NO2 AQI              131.0000
# O3 Mean                0.0862
# O3 1st Max Value       0.1400
# O3 1st Max Hour       23.0000
# O3 AQI               218.0000
# SO2 Mean              41.7932
# SO2 1st Max Value    193.3000
# SO2 1st Max Hour      23.0000
# SO2 AQI              153.0000
# CO Mean                7.9083
# CO 1st Max Value      20.3000
# CO 1st Max Hour       23.0000
# CO AQI               201.0000

# %%
#Midrange of the attributes 
df.loc['midrange'] = (df.loc['max'] + df.loc['min']) / 2
pd.DataFrame(df.loc['midrange'])
# Out:
#                      midrange
# id                 24579.5000
# State Code             6.0000
# County Code           56.0000
# Site Num            4001.0000
# NO2 Mean              48.1295
# NO2 1st Max Value    130.2000
# NO2 1st Max Hour      11.5000
# NO2 AQI               65.5000
# O3 Mean                0.0431
# O3 1st Max Value       0.0700
# O3 1st Max Hour       11.5000
# O3 AQI               109.0000
# SO2 Mean              19.3748
# SO2 1st Max Value     95.3500
# SO2 1st Max Hour      11.5000
# SO2 AQI               76.5000
# CO Mean                3.5542
# CO 1st Max Value       9.7500
# CO 1st Max Hour       11.5000
# CO AQI               100.5000

# %%
#Median of the attributes(which is the middle number in the sorted tuples) 
df.loc['median'] = data.median()
pd.DataFrame(df.loc['median'])
# Out:
#                        median
# id                 24450.0000
# State Code             6.0000
# County Code           65.0000
# Site Num            1004.0000
# NO2 Mean              10.9440
# NO2 1st Max Value     23.0000
# NO2 1st Max Hour       9.0000
# NO2 AQI               22.0000
# O3 Mean                0.0260
# O3 1st Max Value       0.0380
# O3 1st Max Hour       10.0000
# O3 AQI                32.0000
# SO2 Mean               0.7600
# SO2 1st Max Value      1.3000
# SO2 1st Max Hour       8.0000
# SO2 AQI                3.0000
# CO Mean                0.3435
# CO 1st Max Value       0.5000
# CO 1st Max Hour        6.0000
# CO AQI                 6.0000

# %% [markdown]
# Based on the mode of the attributes, most of the data is from Los Angeles, California.
# <br>Mode of AQI for the four pollutants show that most of the times the air quality were *Good*.

# %%
data.iloc[:,5:].mode()
# Out:
#         State       County         City Date Local  NO2 Mean  \
# 0  California  Los Angeles  Los Angeles  5/24/2011       0.0
#
#    NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI  O3 Mean  O3 1st Max Value  \
# 0                1.0                 6        8     0.03             0.039
#
#    O3 1st Max Hour  O3 AQI  SO2 Mean  SO2 1st Max Value  SO2 1st Max Hour  \
# 0               10      31       0.0                1.0                 8
#
#    SO2 AQI  CO Mean  CO 1st Max Value  CO 1st Max Hour  CO AQI
# 0      1.0      0.2               0.3                0     3.0

# %%
#IQR of the attributes(which is the Interquartile Range) 
df.loc['IQR'] = df.loc['75%'] - df.loc['25%']
pd.DataFrame(df.loc['IQR'])
# Out:
#                           IQR
# id                 18004.7500
# State Code             0.0000
# County Code           50.0000
# Site Num            2001.0000
# NO2 Mean              14.3636
# NO2 1st Max Value     26.0000
# NO2 1st Max Hour      13.0000
# NO2 AQI               25.0000
# O3 Mean                0.0163
# O3 1st Max Value       0.0180
# O3 1st Max Hour        2.0000
# O3 AQI                15.0000
# SO2 Mean               1.3994
# SO2 1st Max Value      2.4000
# SO2 1st Max Hour      10.0000
# SO2 AQI                3.0000
# CO Mean                0.3313
# CO 1st Max Value       0.7000
# CO 1st Max Hour       10.0000
# CO AQI                 6.0000

# %%
#Skew of the attributes(which is the measure of the asymmetry of the distribution) 
df.loc['skew'] = data.skew()
pd.DataFrame(df.loc['skew'])
# Out:
#                      skew
# id                -0.0023
# State Code         0.0000
# County Code       -0.2433
# Site Num           1.7641
# NO2 Mean           1.2664
# NO2 1st Max Value  1.0530
# NO2 1st Max Hour   0.1300
# NO2 AQI            1.0288
# O3 Mean            0.1792
# O3 1st Max Value   0.6524
# O3 1st Max Hour    0.7320
# O3 AQI             2.8076
# SO2 Mean           2.7356
# SO2 1st Max Value  7.7370
# SO2 1st Max Hour   0.5341
# SO2 AQI            4.9107
# CO Mean            2.7044
# CO 1st Max Value   3.7798
# CO 1st Max Hour    0.8879
# CO AQI             3.4229

# %%
#Covariance measures the strength and the dicrection of relationship between the observations of two attributes
covariance = data.cov()
#covariance.iloc[4: , 4: ]
covariance.loc['NO2 Mean': , 'NO2 Mean':]
# Out:
#                    NO2 Mean  NO2 1st Max Value  NO2 1st Max Hour   NO2 AQI  \
# NO2 Mean           122.8090           185.1406           12.9256  176.1480
# NO2 1st Max Value  185.1406           324.9582           21.1104  308.2862
# NO2 1st Max Hour    12.9256            21.1104           54.4389   19.8772
# NO2 AQI            176.1480           308.2862           19.8772  293.4343
# O3 Mean             -0.0634            -0.0801           -0.0227   -0.0758
# O3 1st Max Value    -0.0253            -0.0075           -0.0161   -0.0070
# O3 1st Max Hour     -0.1369            -0.2460           -3.3721   -0.2533
# O3 AQI             -14.9626            12.3979          -19.3498   11.7490
# SO2 Mean             5.4210             8.5008            0.1266    8.1585
# SO2 1st Max Value   11.5869            18.9040            0.1525   18.1354
# SO2 1st Max Hour     9.5777            15.6278            7.7506   14.6686
# SO2 AQI             19.0637            31.0776            0.0999   29.8779
# CO Mean              3.0327             4.5429            0.3520    4.3305
# CO 1st Max Value     5.9967             9.5951            0.7188    9.1412
# CO 1st Max Hour     16.6835            31.4979           19.1827   29.8141
# CO AQI              56.6887            88.7338            5.9671   84.5327
#
#                    O3 Mean  O3 1st Max Value  O3 1st Max Hour    O3 AQI  \
# NO2 Mean           -0.0634           -0.0253          -0.1369  -14.9626
# NO2 1st Max Value  -0.0801           -0.0075          -0.2460   12.3979
# NO2 1st Max Hour   -0.0227           -0.0161          -3.3721  -19.3498
# NO2 AQI            -0.0758           -0.0070          -0.2533   11.7490
# O3 Mean             0.0001            0.0001           0.0020    0.1682
# O3 1st Max Value    0.0001            0.0002           0.0029    0.2845
# O3 1st Max Hour     0.0020            0.0029          13.7746    3.2536
# O3 AQI              0.1682            0.2845           3.2536  417.4824
# SO2 Mean           -0.0019           -0.0006          -0.0026   -0.4963
# SO2 1st Max Value  -0.0045           -0.0015           0.1616   -1.7432
# SO2 1st Max Hour   -0.0089           -0.0040          -0.6306   -2.3672
# SO2 AQI            -0.0073           -0.0027           0.2794   -3.4241
# CO Mean            -0.0020           -0.0015          -0.0279   -1.4172
# CO 1st Max Value   -0.0041           -0.0028          -0.0668   -2.6974
# CO 1st Max Hour    -0.0198           -0.0135          -2.8438  -14.4925
# CO AQI             -0.0382           -0.0271          -0.4060  -25.7735
#
#                    SO2 Mean  SO2 1st Max Value  SO2 1st Max Hour  SO2 AQI  \
# NO2 Mean             5.4210            11.5869            9.5777  19.0637
# NO2 1st Max Value    8.5008            18.9040           15.6278  31.0776
# NO2 1st Max Hour     0.1266             0.1525            7.7506   0.0999
# NO2 AQI              8.1585            18.1354           14.6686  29.8779
# O3 Mean             -0.0019            -0.0045           -0.0089  -0.0073
# O3 1st Max Value    -0.0006            -0.0015           -0.0040  -0.0027
# O3 1st Max Hour     -0.0026             0.1616           -0.6306   0.2794
# O3 AQI              -0.4963            -1.7432           -2.3672  -3.4241
# SO2 Mean             1.9778             3.6165            1.4423   5.8224
# SO2 1st Max Value    3.6165            10.2229            4.2069  18.9823
# SO2 1st Max Hour     1.4423             4.2069           39.9779   8.0875
# SO2 AQI              5.8224            18.9823            8.0875  26.9977
# CO Mean              0.1827             0.3639            0.2629   0.6030
# CO 1st Max Value     0.3385             0.7293            0.6172   1.2047
# CO 1st Max Hour      0.7240             1.4553            7.6628   2.3337
# CO AQI               3.1978             6.6793            4.9992  11.0099
#
#                    CO Mean  CO 1st Max Value  CO 1st Max Hour   CO AQI
# NO2 Mean            3.0327            5.9967          16.6835  56.6887
# NO2 1st Max Value   4.5429            9.5951          31.4979  88.7338
# NO2 1st Max Hour    0.3520            0.7188          19.1827   5.9671
# NO2 AQI             4.3305            9.1412          29.8141  84.5327
# O3 Mean            -0.0020           -0.0041          -0.0198  -0.0382
# O3 1st Max Value   -0.0015           -0.0028          -0.0135  -0.0271
# O3 1st Max Hour    -0.0279           -0.0668          -2.8438  -0.4060
# O3 AQI             -1.4172           -2.6974         -14.4925 -25.7735
# SO2 Mean            0.1827            0.3385           0.7240   3.1978
# SO2 1st Max Value   0.3639            0.7293           1.4553   6.6793
# SO2 1st Max Hour    0.2629            0.6172           7.6628   4.9992
# SO2 AQI             0.6030            1.2047           2.3337  11.0099
# CO Mean             0.1413            0.2669           0.4215   2.5890
# CO 1st Max Value    0.2669            0.6378           1.2104   4.5191
# CO 1st Max Hour     0.4215            1.2104          52.3237   9.9796
# CO AQI              2.5890            4.5191           9.9796  51.6069

# %% [markdown]
# ### Correlation Analysis

# %% [markdown]
# Below is the pearson correlation between the attributes as well as the heatmap to better visualize it.

# %%
correlations = data.corr(method = 'pearson')
correlations.loc['NO2 Mean': , 'NO2 Mean':]
# Out:
#                    NO2 Mean  NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI  \
# NO2 Mean             1.0000             0.9268            0.1581   0.9279
# NO2 1st Max Value    0.9268             1.0000            0.1587   0.9984
# NO2 1st Max Hour     0.1581             0.1587            1.0000   0.1573
# NO2 AQI              0.9279             0.9984            0.1573   1.0000
# O3 Mean             -0.4964            -0.3856           -0.2669  -0.3839
# O3 1st Max Value    -0.1518            -0.0277           -0.1454  -0.0271
# O3 1st Max Hour     -0.0033            -0.0037           -0.1231  -0.0040
# O3 AQI              -0.0661             0.0337           -0.1284   0.0336
# SO2 Mean             0.3478             0.3353            0.0122   0.3387
# SO2 1st Max Value    0.3270             0.3280            0.0065   0.3311
# SO2 1st Max Hour     0.1367             0.1371            0.1661   0.1354
# SO2 AQI              0.3310             0.3318            0.0026   0.3357
# CO Mean              0.7281             0.6705            0.1269   0.6726
# CO 1st Max Value     0.6776             0.6665            0.1220   0.6682
# CO 1st Max Hour      0.2081             0.2416            0.3594   0.2406
# CO AQI               0.7120             0.6852            0.1126   0.6869
#
#                    O3 Mean  O3 1st Max Value  O3 1st Max Hour  O3 AQI  \
# NO2 Mean           -0.4964           -0.1518          -0.0033 -0.0661
# NO2 1st Max Value  -0.3856           -0.0277          -0.0037  0.0337
# NO2 1st Max Hour   -0.2669           -0.1454          -0.1231 -0.1284
# NO2 AQI            -0.3839           -0.0271          -0.0040  0.0336
# O3 Mean             1.0000            0.8307           0.0473  0.7139
# O3 1st Max Value    0.8307            1.0000           0.0514  0.9266
# O3 1st Max Hour     0.0473            0.0514           1.0000  0.0429
# O3 AQI              0.7139            0.9266           0.0429  1.0000
# SO2 Mean           -0.1194           -0.0262          -0.0005 -0.0173
# SO2 1st Max Value  -0.1228           -0.0322           0.0136 -0.0267
# SO2 1st Max Hour   -0.1219           -0.0423          -0.0269 -0.0183
# SO2 AQI            -0.1211           -0.0342           0.0145 -0.0323
# CO Mean            -0.4624           -0.2646          -0.0200 -0.1845
# CO 1st Max Value   -0.4412           -0.2339          -0.0225 -0.1653
# CO 1st Max Hour    -0.2373           -0.1241          -0.1059 -0.0981
# CO AQI             -0.4607           -0.2508          -0.0152 -0.1756
#
#                    SO2 Mean  SO2 1st Max Value  SO2 1st Max Hour  SO2 AQI  \
# NO2 Mean             0.3478             0.3270            0.1367   0.3310
# NO2 1st Max Value    0.3353             0.3280            0.1371   0.3318
# NO2 1st Max Hour     0.0122             0.0065            0.1661   0.0026
# NO2 AQI              0.3387             0.3311            0.1354   0.3357
# O3 Mean             -0.1194            -0.1228           -0.1219  -0.1211
# O3 1st Max Value    -0.0262            -0.0322           -0.0423  -0.0342
# O3 1st Max Hour     -0.0005             0.0136           -0.0269   0.0145
# O3 AQI              -0.0173            -0.0267           -0.0183  -0.0323
# SO2 Mean             1.0000             0.8043            0.1622   0.7986
# SO2 1st Max Value    0.8043             1.0000            0.2081   0.9899
# SO2 1st Max Hour     0.1622             0.2081            1.0000   0.2467
# SO2 AQI              0.7986             0.9899            0.2467   1.0000
# CO Mean              0.3456             0.3028            0.1106   0.3088
# CO 1st Max Value     0.3014             0.2856            0.1222   0.2904
# CO 1st Max Hour      0.0712             0.0629            0.1675   0.0621
# CO AQI               0.3164             0.2908            0.1101   0.2949
#
#                    CO Mean  CO 1st Max Value  CO 1st Max Hour  CO AQI
# NO2 Mean            0.7281            0.6776           0.2081  0.7120
# NO2 1st Max Value   0.6705            0.6665           0.2416  0.6852
# NO2 1st Max Hour    0.1269            0.1220           0.3594  0.1126
# NO2 AQI             0.6726            0.6682           0.2406  0.6869
# O3 Mean            -0.4624           -0.4412          -0.2373 -0.4607
# O3 1st Max Value   -0.2646           -0.2339          -0.1241 -0.2508
# O3 1st Max Hour    -0.0200           -0.0225          -0.1059 -0.0152
# O3 AQI             -0.1845           -0.1653          -0.0981 -0.1756
# SO2 Mean            0.3456            0.3014           0.0712  0.3164
# SO2 1st Max Value   0.3028            0.2856           0.0629  0.2908
# SO2 1st Max Hour    0.1106            0.1222           0.1675  0.1101
# SO2 AQI             0.3088            0.2904           0.0621  0.2949
# CO Mean             1.0000            0.8893           0.1550  0.9498
# CO 1st Max Value    0.8893            1.0000           0.2095  0.9988
# CO 1st Max Hour     0.1550            0.2095           1.0000  0.1921
# CO AQI              0.9498            0.9988           0.1921  1.0000

# %% [markdown]
# * In the graph we can see all the pollutants, AQI has a high correlation with its 1st Max Value(>0.9).
# * AQI and its Mean are also highly correlated(>0.7).
# * O3 Mean is negatively correlated with other pollutants mean.
# * SO2, NO2 and CO Mean are posisively correlated.

# %%
fig, ax = plt.subplots(figsize=(12,12))  
set_option('precision', 2)
sns.heatmap(correlations.loc['NO2 Mean': , 'NO2 Mean':], vmin = -1, vmax= 1, cmap = 'YlGnBu', annot = True)

# %%
#This is a test code
count = 0
for i in range(0, len(data)-4, 4):
    avg = (data.loc[i, 'NO2 1st Max Value']+data.loc[i+1, 'NO2 1st Max Value']+data.loc[i+2, 'NO2 1st Max Value']+data.loc[i+3, 'NO2 1st Max Value'])/4
    if(avg != data.loc[i, 'NO2 1st Max Value']):
        count+=1
        if(count == 2):
            print(i)
            break
# Out:
# 7148

# %%
data['County'].value_counts().sort_values(ascending = False).plot(kind = 'bar')

# %%
data['City'].value_counts().sort_values(ascending = False).plot(kind = 'bar')

# %%
cityRecords = pd.DataFrame(data['City'].value_counts().sort_values(ascending = False))
cityRecords.reset_index(inplace=True)
cityRecords.iloc[:, 0]
plt.figure(figsize=(10, 5))
plt.bar(cityRecords.iloc[:, 0], cityRecords.iloc[:, 1], color = 'k')
plt.title("Number of tuples for each city")
plt.xlabel("City")
plt.ylabel("Number of records")
plt.xticks(rotation=90)
#plt.style.available
plt.style.use('fivethirtyeight')
plt.savefig('test.png')
plt.show()

# %%
data['Date Local'] = pd.to_datetime(data['Date Local'],format='%m/%d/%Y')
dateRecords = data.groupby([data['Date Local'].dt.year], as_index=False).agg('count')
dateRecords.reset_index(inplace=True)
dateRecords.iloc[:, 0]
plt.figure(figsize=(5, 10))
plt.bar(list(range(2000,2017)), dateRecords.iloc[:, 8], color = 'k', orientation = 'vertical')
plt.title("Number of records per year")
plt.xlabel("Year")
plt.ylabel("Number of records")
plt.xticks(rotation=90)
#plt.style.available
#plt.style.use('ggplot')
plt.savefig('test.png')
plt.show()

# %%
print(list(range(2000,2016)))
# Out:
# [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015]

# %%
dateRecords.iloc[:, 8]
# Out:
# 0     34790
# 1     37221
# 2     38932
# 3     36858
# 4     33805
# 5     34686
# 6     34177
# 7     37081
# 8     41042
# 9     35700
# 10    33240
# 11    37414
# 12    32948
# 13    35820
# 14    34086
# 15    32842
# 16     5500
# Name: City, dtype: int64

# %%
np.arange(2000,2017)
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016])
